# %% [markdown]
# <a href="https://colab.research.google.com/github/PravinHaligonda/random-fun/blob/main/AlexNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import random
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision
import torch.nn.functional as F
from torchvision import transforms
from torchvision import datasets
from torch.utils.data import DataLoader
from torch.utils.data import sampler
from torch.utils.data import SubsetRandomSampler

# %%
def get_cifar10_dataset(batch_size, num_workers=0, validation_fraction=None, train_transform=None, test_transform=None):
  if train_transform is None:
    train_transform = transforms.ToTensor()
  if test_transform is None:
    test_transform = transforms.ToTensor()

  train_dataset = datasets.CIFAR10(root="cifar10", train=True, download=True, transform=train_transform)
  valid_dataset = datasets.CIFAR10(root="cifar10", train=True, download=True, transform=test_transform)
  test_dataset = datasets.CIFAR10(root="cifar-10", train=False, download=True, transform=test_transform)

  if validation_fraction is not None:
    num = int(validation_fraction * 50000)
    train_indices = torch.arange(0, 50000 - num)
    valid_indices = torch.arange(50000 - num, 50000)
    train_sampler = SubsetRandomSampler(train_indices)
    valid_sampler = SubsetRandomSampler(valid_indices)

    valid_loader = DataLoader(valid_dataset, batch_size=batch_size, num_workers=num_workers, sampler=valid_sampler)
    train_loader = DataLoader(train_dataset, batch_size=batch_size, num_workers=num_workers, drop_last=True, sampler=train_sampler)
  else:
    train_loader = DataLoader(train_dataset, batch_size=batch_size, num_workers=num_workers, shuffle=True)
  test_loader = DataLoader(test_dataset, batch_size=batch_size, num_workers=num_workers, shuffle=False)

  if validation_fraction is not None:
    return train_loader, valid_loader, test_loader
  else:
    return train_loader, test_loader

# %%
RANDOM_SEED = 123
BATCH_SIZE = 256
NUM_EPOCHS = 200
DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
def set_all_seeds(seed):
    os.environ["PL_GLOBAL_SEED"] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

# %%
set_all_seeds(RANDOM_SEED)

# %%
train_transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize((70, 70)),
    torchvision.transforms.RandomCrop((64, 64)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
                                      ])

test_transforms = torchvision.transforms.Compose([
    torchvision.transforms.Resize((70, 70)),
    torchvision.transforms.CenterCrop((64, 64)),
    torchvision.transforms.ToTensor(),
    torchvision.transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

# %%
train_loader, valid_loader, test_loader = get_cifar10_dataset(BATCH_SIZE, train_transform=train_transforms, test_transform=test_transforms, num_workers=2, validation_fraction=0.1)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to cifar10/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:12<00:00, 13.2MB/s]
# Extracting cifar10/cifar-10-python.tar.gz to cifar10
# Files already downloaded and verified
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to cifar-10/cifar-10-python.tar.gz
# 100%|██████████| 170M/170M [00:12<00:00, 13.2MB/s]
# Extracting cifar-10/cifar-10-python.tar.gz to cifar-10

# %%
# Checking the dataset
for images, labels in train_loader:
    print('Image batch dimensions:', images.shape)
    print('Image label dimensions:', labels.shape)
    print('Class labels of 10 examples:', labels[:10])
    break
# Out:
# Image batch dimensions: torch.Size([256, 3, 64, 64])
# Image label dimensions: torch.Size([256])
# Class labels of 10 examples: tensor([4, 7, 4, 6, 2, 6, 9, 7, 3, 0])

# %%
class AlexNet(torch.nn.Module):

    def __init__(self, num_classes):
        super().__init__()
        self.features = torch.nn.Sequential(
            torch.nn.Conv2d(3, 64, kernel_size=11, stride=4, padding=2),
            torch.nn.ReLU(inplace=True),
            torch.nn.MaxPool2d(kernel_size=3, stride=2),
            torch.nn.Conv2d(64, 192, kernel_size=5, padding=2),
            torch.nn.ReLU(inplace=True),
            torch.nn.MaxPool2d(kernel_size=3, stride=2),
            torch.nn.Conv2d(192, 384, kernel_size=3, padding=1),
            torch.nn.ReLU(inplace=True),
            torch.nn.Conv2d(384, 256, kernel_size=3, padding=1),
            torch.nn.ReLU(inplace=True),
            torch.nn.Conv2d(256, 256, kernel_size=3, padding=1),
            torch.nn.ReLU(inplace=True),
            torch.nn.MaxPool2d(kernel_size=3, stride=2),
        )
        self.avgpool = torch.nn.AdaptiveAvgPool2d((6, 6))
        self.classifier = torch.nn.Sequential(
            torch.nn.Dropout(0.5),
            torch.nn.Linear(256 * 6 * 6, 4096),
            torch.nn.ReLU(inplace=True),
            torch.nn.Dropout(0.5),
            torch.nn.Linear(4096, 4096),
            torch.nn.ReLU(inplace=True),
            torch.nn.Linear(4096, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = x.view(x.size(0), 256 * 6 * 6)
        logits = self.classifier(x)
        return logits

# %%
model = AlexNet(num_classes=10)

model = model.to(DEVICE)

optimizer = torch.optim.SGD(model.parameters(), momentum=0.9, lr=0.1)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer,
                                                       factor=0.1,
                                                       mode='max',
                                                       verbose=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(

# %%
def compute_accuracy(model, data_loader, device):

    with torch.no_grad():

        correct_pred, num_examples = 0, 0

        for i, (features, targets) in enumerate(data_loader):

            features = features.to(device)
            targets = targets.float().to(device)

            logits = model(features)
            _, predicted_labels = torch.max(logits, 1)

            num_examples += targets.size(0)
            correct_pred += (predicted_labels == targets).sum()
    return correct_pred.float()/num_examples * 100

# %%
import time
def train_model(model, num_epochs, train_loader,
                valid_loader, test_loader, optimizer,
                device, logging_interval=50,
                scheduler=None,
                scheduler_on='valid_acc'):

    start_time = time.time()
    minibatch_loss_list, train_acc_list, valid_acc_list = [], [], []

    for epoch in range(num_epochs):

        model.train()
        for batch_idx, (features, targets) in enumerate(train_loader):

            features = features.to(device)
            targets = targets.to(device)

            # ## FORWARD AND BACK PROP
            logits = model(features)
            loss = torch.nn.functional.cross_entropy(logits, targets)
            optimizer.zero_grad()

            loss.backward()

            # ## UPDATE MODEL PARAMETERS
            optimizer.step()

            # ## LOGGING
            minibatch_loss_list.append(loss.item())
            if not batch_idx % logging_interval:
                print(f'Epoch: {epoch+1:03d}/{num_epochs:03d} '
                      f'| Batch {batch_idx:04d}/{len(train_loader):04d} '
                      f'| Loss: {loss:.4f}')

        model.eval()
        with torch.no_grad():  # save memory during inference
            train_acc = compute_accuracy(model, train_loader, device=device)
            valid_acc = compute_accuracy(model, valid_loader, device=device)
            print(f'Epoch: {epoch+1:03d}/{num_epochs:03d} '
                  f'| Train: {train_acc :.2f}% '
                  f'| Validation: {valid_acc :.2f}%')
            train_acc_list.append(train_acc.item())
            valid_acc_list.append(valid_acc.item())

        elapsed = (time.time() - start_time)/60
        print(f'Time elapsed: {elapsed:.2f} min')

        if scheduler is not None:

            if scheduler_on == 'valid_acc':
                scheduler.step(valid_acc_list[-1])
            elif scheduler_on == 'minibatch_loss':
                scheduler.step(minibatch_loss_list[-1])
            else:
                raise ValueError(f'Invalid `scheduler_on` choice.')


    elapsed = (time.time() - start_time)/60
    print(f'Total Training Time: {elapsed:.2f} min')

    test_acc = compute_accuracy(model, test_loader, device=device)
    print(f'Test accuracy {test_acc :.2f}%')

    return minibatch_loss_list, train_acc_list, valid_acc_list

# %%
minibatch_loss_list, train_acc_list, valid_acc_list = train_model(
    model=model,
    num_epochs=NUM_EPOCHS,
    train_loader=train_loader,
    valid_loader=valid_loader,
    test_loader=test_loader,
    optimizer=optimizer,
    device=DEVICE,
    scheduler=scheduler,
    scheduler_on='valid_acc',
    logging_interval=100)
# Out:
# Epoch: 001/200 | Batch 0000/0175 | Loss: 2.3024
# Epoch: 001/200 | Batch 0100/0175 | Loss: 2.2897
# Epoch: 001/200 | Train: 19.02% | Validation: 19.50%
# Time elapsed: 0.80 min
# Epoch: 002/200 | Batch 0000/0175 | Loss: 1.9228
# Epoch: 002/200 | Batch 0100/0175 | Loss: 2.0369
# Epoch: 002/200 | Train: 31.82% | Validation: 31.58%
# Time elapsed: 1.60 min
# Epoch: 003/200 | Batch 0000/0175 | Loss: 1.7385
# Epoch: 003/200 | Batch 0100/0175 | Loss: 1.5934
# Epoch: 003/200 | Train: 43.78% | Validation: 43.84%
# Time elapsed: 2.41 min
# Epoch: 004/200 | Batch 0000/0175 | Loss: 1.4438
# Epoch: 004/200 | Batch 0100/0175 | Loss: 1.4648
# Epoch: 004/200 | Train: 52.86% | Validation: 53.06%
# Time elapsed: 3.18 min
# Epoch: 005/200 | Batch 0000/0175 | Loss: 1.4159
# Epoch: 005/200 | Batch 0100/0175 | Loss: 1.1932
# Epoch: 005/200 | Train: 58.26% | Validation: 58.66%
# Time elapsed: 3.98 min
# Epoch: 006/200 | Batch 0000/0175 | Loss: 1.2473
# Epoch: 006/200 | Batch 0100/0175 | Loss: 1.2922
# Epoch: 006/200 | Train: 62.08% | Validation: 61.52%
# Time elapsed: 4.77 min
# Epoch: 007/200 | Batch 0000/0175 | Loss: 1.1970
# Epoch: 007/200 | Batch 0100/0175 | Loss: 1.1015
# Epoch: 007/200 | Train: 66.12% | Validation: 64.70%
# Time elapsed: 5.55 min
# Epoch: 008/200 | Batch 0000/0175 | Loss: 0.9389
# Epoch: 008/200 | Batch 0100/0175 | Loss: 1.1989
# Epoch: 008/200 | Train: 64.88% | Validation: 64.12%
# Time elapsed: 6.34 min
# Epoch: 009/200 | Batch 0000/0175 | Loss: 0.9546
# Epoch: 009/200 | Batch 0100/0175 | Loss: 1.0415
# Epoch: 009/200 | Train: 68.40% | Validation: 66.12%
# Time elapsed: 7.10 min
# Epoch: 010/200 | Batch 0000/0175 | Loss: 0.9577
# Epoch: 010/200 | Batch 0100/0175 | Loss: 0.8355
# Epoch: 010/200 | Train: 70.86% | Validation: 67.86%
# Time elapsed: 7.88 min
# Epoch: 011/200 | Batch 0000/0175 | Loss: 0.8498
# Epoch: 011/200 | Batch 0100/0175 | Loss: 0.9297
# Epoch: 011/200 | Train: 71.80% | Validation: 69.70%
# Time elapsed: 8.65 min
# Epoch: 012/200 | Batch 0000/0175 | Loss: 0.9108
# Epoch: 012/200 | Batch 0100/0175 | Loss: 0.8839
# Epoch: 012/200 | Train: 74.11% | Validation: 69.90%
# Time elapsed: 9.44 min
# Epoch: 013/200 | Batch 0000/0175 | Loss: 0.8897
# Epoch: 013/200 | Batch 0100/0175 | Loss: 0.6103
# Epoch: 013/200 | Train: 74.55% | Validation: 70.32%
# Time elapsed: 10.23 min
# Epoch: 014/200 | Batch 0000/0175 | Loss: 0.8226
# Epoch: 014/200 | Batch 0100/0175 | Loss: 0.7414
# Epoch: 014/200 | Train: 73.62% | Validation: 69.16%
# Time elapsed: 11.00 min
# Epoch: 015/200 | Batch 0000/0175 | Loss: 0.8285
# Epoch: 015/200 | Batch 0100/0175 | Loss: 0.7805
# Epoch: 015/200 | Train: 76.01% | Validation: 71.04%
# Time elapsed: 11.80 min
# Epoch: 016/200 | Batch 0000/0175 | Loss: 0.8646
# Epoch: 016/200 | Batch 0100/0175 | Loss: 0.8446
# Epoch: 016/200 | Train: 75.24% | Validation: 70.80%
# Time elapsed: 12.56 min
# Epoch: 017/200 | Batch 0000/0175 | Loss: 0.8362
# Epoch: 017/200 | Batch 0100/0175 | Loss: 0.7545
# Epoch: 017/200 | Train: 76.15% | Validation: 71.58%
# Time elapsed: 13.35 min
# Epoch: 018/200 | Batch 0000/0175 | Loss: 0.6554
# Epoch: 018/200 | Batch 0100/0175 | Loss: 0.5896
# Epoch: 018/200 | Train: 76.20% | Validation: 70.34%
# Time elapsed: 14.15 min
# Epoch: 019/200 | Batch 0000/0175 | Loss: 0.7360
# Epoch: 019/200 | Batch 0100/0175 | Loss: 0.6624
# Epoch: 019/200 | Train: 77.18% | Validation: 71.08%
# Time elapsed: 14.93 min
# Epoch: 020/200 | Batch 0000/0175 | Loss: 0.7280
# Epoch: 020/200 | Batch 0100/0175 | Loss: 0.7585
# Epoch: 020/200 | Train: 76.15% | Validation: 70.96%
# Time elapsed: 15.73 min
# Epoch: 021/200 | Batch 0000/0175 | Loss: 0.8124
# Epoch: 021/200 | Batch 0100/0175 | Loss: 0.8821
# Epoch: 021/200 | Train: 77.14% | Validation: 71.86%
# Time elapsed: 16.51 min
# Epoch: 022/200 | Batch 0000/0175 | Loss: 0.6521
# Epoch: 022/200 | Batch 0100/0175 | Loss: 0.8099
# Epoch: 022/200 | Train: 77.19% | Validation: 70.46%
# Time elapsed: 17.31 min
# Epoch: 023/200 | Batch 0000/0175 | Loss: 0.8470
# Epoch: 023/200 | Batch 0100/0175 | Loss: 0.7928
# Epoch: 023/200 | Train: 76.62% | Validation: 71.28%
# Time elapsed: 18.11 min
# Epoch: 024/200 | Batch 0000/0175 | Loss: 0.7716
# Epoch: 024/200 | Batch 0100/0175 | Loss: 0.7519
# Epoch: 024/200 | Train: 76.35% | Validation: 70.46%
# Time elapsed: 18.88 min
# Epoch: 025/200 | Batch 0000/0175 | Loss: 0.7832
# Epoch: 025/200 | Batch 0100/0175 | Loss: 0.7497
# Epoch: 025/200 | Train: 73.45% | Validation: 68.84%
# Time elapsed: 19.66 min
# Epoch: 026/200 | Batch 0000/0175 | Loss: 0.6151
# Epoch: 026/200 | Batch 0100/0175 | Loss: 0.7230
# Epoch: 026/200 | Train: 74.50% | Validation: 68.22%
# Time elapsed: 20.44 min
# Epoch: 027/200 | Batch 0000/0175 | Loss: 0.7774
# Epoch: 027/200 | Batch 0100/0175 | Loss: 0.8160
# Epoch: 027/200 | Train: 72.56% | Validation: 68.32%
# Time elapsed: 21.23 min
# Epoch: 028/200 | Batch 0000/0175 | Loss: 0.9427
# Epoch: 028/200 | Batch 0100/0175 | Loss: 0.9703
# Epoch: 028/200 | Train: 68.82% | Validation: 65.20%
# Time elapsed: 22.03 min
# Epoch: 029/200 | Batch 0000/0175 | Loss: 1.1369
# Epoch: 029/200 | Batch 0100/0175 | Loss: 0.8653
# Epoch: 029/200 | Train: 72.73% | Validation: 68.36%
# Time elapsed: 22.81 min
# Epoch: 030/200 | Batch 0000/0175 | Loss: 0.8530
# Epoch: 030/200 | Batch 0100/0175 | Loss: 0.9100
# Epoch: 030/200 | Train: 64.68% | Validation: 62.50%
# Time elapsed: 23.61 min
# Epoch: 031/200 | Batch 0000/0175 | Loss: 1.2128
# Epoch: 031/200 | Batch 0100/0175 | Loss: 1.0333
# Epoch: 031/200 | Train: 61.94% | Validation: 59.78%
# Time elapsed: 24.39 min
# Epoch: 032/200 | Batch 0000/0175 | Loss: 1.3269
# Epoch: 032/200 | Batch 0100/0175 | Loss: 1.6220
# Epoch: 032/200 | Train: 62.01% | Validation: 60.06%
# Time elapsed: 25.19 min
# Epoch: 033/200 | Batch 0000/0175 | Loss: 1.0824
# Epoch: 033/200 | Batch 0100/0175 | Loss: 0.7559
# Epoch: 033/200 | Train: 76.62% | Validation: 72.56%
# Time elapsed: 25.98 min
# Epoch: 034/200 | Batch 0000/0175 | Loss: 0.7116
# Epoch: 034/200 | Batch 0100/0175 | Loss: 0.6843
# Epoch: 034/200 | Train: 78.72% | Validation: 74.16%
# Time elapsed: 26.76 min
# Epoch: 035/200 | Batch 0000/0175 | Loss: 0.8044
# Epoch: 035/200 | Batch 0100/0175 | Loss: 0.6078
# Epoch: 035/200 | Train: 79.84% | Validation: 73.98%
# Time elapsed: 27.58 min
# Epoch: 036/200 | Batch 0000/0175 | Loss: 0.6042
# Epoch: 036/200 | Batch 0100/0175 | Loss: 0.5881
# Epoch: 036/200 | Train: 80.92% | Validation: 74.80%
# Time elapsed: 28.40 min
# Epoch: 037/200 | Batch 0000/0175 | Loss: 0.5836
# Epoch: 037/200 | Batch 0100/0175 | Loss: 0.5143
# Epoch: 037/200 | Train: 81.79% | Validation: 74.80%
# Time elapsed: 29.18 min
# Epoch: 038/200 | Batch 0000/0175 | Loss: 0.5984
# Epoch: 038/200 | Batch 0100/0175 | Loss: 0.5556
# Epoch: 038/200 | Train: 82.44% | Validation: 75.14%
# Time elapsed: 29.99 min
# Epoch: 039/200 | Batch 0000/0175 | Loss: 0.6215
# Epoch: 039/200 | Batch 0100/0175 | Loss: 0.4896
# Epoch: 039/200 | Train: 83.13% | Validation: 75.16%
# Time elapsed: 30.79 min
# Epoch: 040/200 | Batch 0000/0175 | Loss: 0.4845
# Epoch: 040/200 | Batch 0100/0175 | Loss: 0.4975
# Epoch: 040/200 | Train: 83.85% | Validation: 75.78%
# Time elapsed: 31.59 min
# Epoch: 041/200 | Batch 0000/0175 | Loss: 0.4349
# Epoch: 041/200 | Batch 0100/0175 | Loss: 0.4418
# Epoch: 041/200 | Train: 84.47% | Validation: 76.12%
# Time elapsed: 32.41 min
# Epoch: 042/200 | Batch 0000/0175 | Loss: 0.4738
# Epoch: 042/200 | Batch 0100/0175 | Loss: 0.5201
# Epoch: 042/200 | Train: 84.95% | Validation: 75.80%
# Time elapsed: 33.23 min
# Epoch: 043/200 | Batch 0000/0175 | Loss: 0.4728
# Epoch: 043/200 | Batch 0100/0175 | Loss: 0.3716
# Epoch: 043/200 | Train: 85.42% | Validation: 75.84%
# Time elapsed: 34.02 min
# Epoch: 044/200 | Batch 0000/0175 | Loss: 0.5051
# Epoch: 044/200 | Batch 0100/0175 | Loss: 0.4102
# Epoch: 044/200 | Train: 85.71% | Validation: 76.54%
# Time elapsed: 34.82 min
# Epoch: 045/200 | Batch 0000/0175 | Loss: 0.4254
# Epoch: 045/200 | Batch 0100/0175 | Loss: 0.4353
# Epoch: 045/200 | Train: 86.28% | Validation: 76.38%
# Time elapsed: 35.63 min
# Epoch: 046/200 | Batch 0000/0175 | Loss: 0.4065
# Epoch: 046/200 | Batch 0100/0175 | Loss: 0.4065
# Epoch: 046/200 | Train: 87.18% | Validation: 76.38%
# Time elapsed: 36.42 min
# Epoch: 047/200 | Batch 0000/0175 | Loss: 0.3468
# Epoch: 047/200 | Batch 0100/0175 | Loss: 0.4109
# Epoch: 047/200 | Train: 87.65% | Validation: 76.68%
# Time elapsed: 37.25 min
# Epoch: 048/200 | Batch 0000/0175 | Loss: 0.3366
# Epoch: 048/200 | Batch 0100/0175 | Loss: 0.4161
# Epoch: 048/200 | Train: 87.91% | Validation: 77.24%
# Time elapsed: 38.08 min
# Epoch: 049/200 | Batch 0000/0175 | Loss: 0.3552
# Epoch: 049/200 | Batch 0100/0175 | Loss: 0.3577
# Epoch: 049/200 | Train: 88.48% | Validation: 77.36%
# Time elapsed: 38.89 min
# Epoch: 050/200 | Batch 0000/0175 | Loss: 0.3658
# Epoch: 050/200 | Batch 0100/0175 | Loss: 0.2801
# Epoch: 050/200 | Train: 89.01% | Validation: 76.82%
# Time elapsed: 39.68 min
# Epoch: 051/200 | Batch 0000/0175 | Loss: 0.3754
# Epoch: 051/200 | Batch 0100/0175 | Loss: 0.4024
# Epoch: 051/200 | Train: 88.85% | Validation: 76.64%
# Time elapsed: 40.48 min
# Epoch: 052/200 | Batch 0000/0175 | Loss: 0.3299
# Epoch: 052/200 | Batch 0100/0175 | Loss: 0.3235
# Epoch: 052/200 | Train: 89.68% | Validation: 76.86%
# Time elapsed: 41.26 min
# Epoch: 053/200 | Batch 0000/0175 | Loss: 0.2893
# Epoch: 053/200 | Batch 0100/0175 | Loss: 0.2429
# Epoch: 053/200 | Train: 90.15% | Validation: 77.14%
# Time elapsed: 42.06 min
# Epoch: 054/200 | Batch 0000/0175 | Loss: 0.2956
# Epoch: 054/200 | Batch 0100/0175 | Loss: 0.3299
# Epoch: 054/200 | Train: 90.18% | Validation: 76.98%
# Time elapsed: 42.87 min
# Epoch: 055/200 | Batch 0000/0175 | Loss: 0.2982
# Epoch: 055/200 | Batch 0100/0175 | Loss: 0.2519
# Epoch: 055/200 | Train: 90.82% | Validation: 76.80%
# Time elapsed: 43.66 min
# Epoch: 056/200 | Batch 0000/0175 | Loss: 0.2331
# Epoch: 056/200 | Batch 0100/0175 | Loss: 0.2510
# Epoch: 056/200 | Train: 91.27% | Validation: 76.64%
# Time elapsed: 44.46 min
# Epoch: 057/200 | Batch 0000/0175 | Loss: 0.2738
# Epoch: 057/200 | Batch 0100/0175 | Loss: 0.2632
# Epoch: 057/200 | Train: 91.75% | Validation: 76.54%
# Time elapsed: 45.25 min
# Epoch: 058/200 | Batch 0000/0175 | Loss: 0.2252
# Epoch: 058/200 | Batch 0100/0175 | Loss: 0.2182
# Epoch: 058/200 | Train: 91.78% | Validation: 76.88%
# Time elapsed: 46.04 min
# Epoch: 059/200 | Batch 0000/0175 | Loss: 0.2290
# Epoch: 059/200 | Batch 0100/0175 | Loss: 0.2551
# Epoch: 059/200 | Train: 92.43% | Validation: 76.60%
# Time elapsed: 46.85 min
# Epoch: 060/200 | Batch 0000/0175 | Loss: 0.2273
# Epoch: 060/200 | Batch 0100/0175 | Loss: 0.3519
# Epoch: 060/200 | Train: 92.91% | Validation: 76.58%
# Time elapsed: 47.65 min
# Epoch: 061/200 | Batch 0000/0175 | Loss: 0.1907
# Epoch: 061/200 | Batch 0100/0175 | Loss: 0.2153
# Epoch: 061/200 | Train: 93.11% | Validation: 76.96%
# Time elapsed: 48.44 min
# Epoch: 062/200 | Batch 0000/0175 | Loss: 0.1477
# Epoch: 062/200 | Batch 0100/0175 | Loss: 0.2723
# Epoch: 062/200 | Train: 93.31% | Validation: 77.04%
# Time elapsed: 49.24 min
# Epoch: 063/200 | Batch 0000/0175 | Loss: 0.2168
# Epoch: 063/200 | Batch 0100/0175 | Loss: 0.1206
# Epoch: 063/200 | Train: 93.48% | Validation: 77.06%
# Time elapsed: 50.03 min
# Epoch: 064/200 | Batch 0000/0175 | Loss: 0.1413
# Epoch: 064/200 | Batch 0100/0175 | Loss: 0.1951
# Epoch: 064/200 | Train: 93.48% | Validation: 76.86%
# Time elapsed: 50.83 min
# Epoch: 065/200 | Batch 0000/0175 | Loss: 0.2307
# Epoch: 065/200 | Batch 0100/0175 | Loss: 0.2760
# Epoch: 065/200 | Train: 93.58% | Validation: 76.80%
# Time elapsed: 51.64 min
# Epoch: 066/200 | Batch 0000/0175 | Loss: 0.1619
# Epoch: 066/200 | Batch 0100/0175 | Loss: 0.1670
# Epoch: 066/200 | Train: 93.85% | Validation: 76.88%
# Time elapsed: 52.43 min
# Epoch: 067/200 | Batch 0000/0175 | Loss: 0.1693
# Epoch: 067/200 | Batch 0100/0175 | Loss: 0.2066
# Epoch: 067/200 | Train: 93.91% | Validation: 76.96%
# Time elapsed: 53.25 min
# Epoch: 068/200 | Batch 0000/0175 | Loss: 0.1284
# Epoch: 068/200 | Batch 0100/0175 | Loss: 0.1448
# Epoch: 068/200 | Train: 93.86% | Validation: 76.96%
# Time elapsed: 54.08 min
# Epoch: 069/200 | Batch 0000/0175 | Loss: 0.1580
# Epoch: 069/200 | Batch 0100/0175 | Loss: 0.2211
# Epoch: 069/200 | Train: 93.87% | Validation: 77.04%
# Time elapsed: 54.90 min
# Epoch: 070/200 | Batch 0000/0175 | Loss: 0.2263
# Epoch: 070/200 | Batch 0100/0175 | Loss: 0.2131
# Epoch: 070/200 | Train: 94.09% | Validation: 76.82%
# Time elapsed: 55.71 min
# Epoch: 071/200 | Batch 0000/0175 | Loss: 0.1467
# Epoch: 071/200 | Batch 0100/0175 | Loss: 0.1428
# Epoch: 071/200 | Train: 94.00% | Validation: 77.04%
# Time elapsed: 56.52 min
# Epoch: 072/200 | Batch 0000/0175 | Loss: 0.2230
# Epoch: 072/200 | Batch 0100/0175 | Loss: 0.2069
# Epoch: 072/200 | Train: 93.98% | Validation: 76.96%
# Time elapsed: 57.35 min
# Epoch: 073/200 | Batch 0000/0175 | Loss: 0.1958
# Epoch: 073/200 | Batch 0100/0175 | Loss: 0.1681
# Epoch: 073/200 | Train: 94.08% | Validation: 77.00%
# Time elapsed: 58.14 min
# Epoch: 074/200 | Batch 0000/0175 | Loss: 0.1382
# Epoch: 074/200 | Batch 0100/0175 | Loss: 0.1555
# Epoch: 074/200 | Train: 94.05% | Validation: 76.96%
# Time elapsed: 58.96 min
# Epoch: 075/200 | Batch 0000/0175 | Loss: 0.1677
# Epoch: 075/200 | Batch 0100/0175 | Loss: 0.1862
# Epoch: 075/200 | Train: 93.99% | Validation: 76.96%
# Time elapsed: 59.77 min
# Epoch: 076/200 | Batch 0000/0175 | Loss: 0.2079
# Epoch: 076/200 | Batch 0100/0175 | Loss: 0.2146
# Epoch: 076/200 | Train: 94.16% | Validation: 76.92%
# Time elapsed: 60.56 min
# Epoch: 077/200 | Batch 0000/0175 | Loss: 0.1631
# Epoch: 077/200 | Batch 0100/0175 | Loss: 0.1902
# Epoch: 077/200 | Train: 94.13% | Validation: 76.88%
# Time elapsed: 61.39 min
# Epoch: 078/200 | Batch 0000/0175 | Loss: 0.1532
# Epoch: 078/200 | Batch 0100/0175 | Loss: 0.1371
# Epoch: 078/200 | Train: 94.12% | Validation: 76.90%
# Time elapsed: 62.21 min
# Epoch: 079/200 | Batch 0000/0175 | Loss: 0.2138
# Epoch: 079/200 | Batch 0100/0175 | Loss: 0.1907
# Epoch: 079/200 | Train: 94.12% | Validation: 76.94%
# Time elapsed: 63.03 min
# Epoch: 080/200 | Batch 0000/0175 | Loss: 0.1738
# Epoch: 080/200 | Batch 0100/0175 | Loss: 0.2180
# Epoch: 080/200 | Train: 94.24% | Validation: 76.98%
# Time elapsed: 63.82 min
# Epoch: 081/200 | Batch 0000/0175 | Loss: 0.1810
# Epoch: 081/200 | Batch 0100/0175 | Loss: 0.2362
# Epoch: 081/200 | Train: 94.27% | Validation: 76.90%
# Time elapsed: 64.64 min
# Epoch: 082/200 | Batch 0000/0175 | Loss: 0.1415
# Epoch: 082/200 | Batch 0100/0175 | Loss: 0.1999
# Epoch: 082/200 | Train: 94.16% | Validation: 76.92%
# Time elapsed: 65.46 min
# Epoch: 083/200 | Batch 0000/0175 | Loss: 0.1563
# Epoch: 083/200 | Batch 0100/0175 | Loss: 0.1810
# Epoch: 083/200 | Train: 94.25% | Validation: 76.92%
# Time elapsed: 66.26 min
# Epoch: 084/200 | Batch 0000/0175 | Loss: 0.1656
# Epoch: 084/200 | Batch 0100/0175 | Loss: 0.1804
# Epoch: 084/200 | Train: 94.16% | Validation: 76.94%
# Time elapsed: 67.09 min
# Epoch: 085/200 | Batch 0000/0175 | Loss: 0.2069
# Epoch: 085/200 | Batch 0100/0175 | Loss: 0.1523
# Epoch: 085/200 | Train: 94.26% | Validation: 76.94%
# Time elapsed: 67.92 min
# Epoch: 086/200 | Batch 0000/0175 | Loss: 0.2323
# Epoch: 086/200 | Batch 0100/0175 | Loss: 0.1801
# Epoch: 086/200 | Train: 94.22% | Validation: 76.92%
# Time elapsed: 68.78 min
# Epoch: 087/200 | Batch 0000/0175 | Loss: 0.1242
# Epoch: 087/200 | Batch 0100/0175 | Loss: 0.2051
# Epoch: 087/200 | Train: 94.23% | Validation: 76.94%
# Time elapsed: 69.58 min
# Epoch: 088/200 | Batch 0000/0175 | Loss: 0.2326
# Epoch: 088/200 | Batch 0100/0175 | Loss: 0.1993
# Epoch: 088/200 | Train: 94.17% | Validation: 76.94%
# Time elapsed: 70.41 min
# Epoch: 089/200 | Batch 0000/0175 | Loss: 0.1254
# Epoch: 089/200 | Batch 0100/0175 | Loss: 0.2883
# Epoch: 089/200 | Train: 94.05% | Validation: 76.90%
# Time elapsed: 71.24 min
# Epoch: 090/200 | Batch 0000/0175 | Loss: 0.1553
# Epoch: 090/200 | Batch 0100/0175 | Loss: 0.1164
# Epoch: 090/200 | Train: 94.25% | Validation: 76.94%
# Time elapsed: 72.07 min
# Epoch: 091/200 | Batch 0000/0175 | Loss: 0.1480
# Epoch: 091/200 | Batch 0100/0175 | Loss: 0.2231
# Epoch: 091/200 | Train: 94.10% | Validation: 76.92%
# Time elapsed: 72.87 min
# Epoch: 092/200 | Batch 0000/0175 | Loss: 0.1989
# Epoch: 092/200 | Batch 0100/0175 | Loss: 0.1439
# Epoch: 092/200 | Train: 94.27% | Validation: 76.90%
# Time elapsed: 73.70 min
# Epoch: 093/200 | Batch 0000/0175 | Loss: 0.1796
# Epoch: 093/200 | Batch 0100/0175 | Loss: 0.2525
# Epoch: 093/200 | Train: 94.21% | Validation: 76.88%
# Time elapsed: 74.52 min
# Epoch: 094/200 | Batch 0000/0175 | Loss: 0.2030
# Epoch: 094/200 | Batch 0100/0175 | Loss: 0.1323
# Epoch: 094/200 | Train: 94.28% | Validation: 76.88%
# Time elapsed: 75.31 min
# Epoch: 095/200 | Batch 0000/0175 | Loss: 0.1342
# Epoch: 095/200 | Batch 0100/0175 | Loss: 0.2335
# Epoch: 095/200 | Train: 94.21% | Validation: 76.88%
# Time elapsed: 76.17 min
# Epoch: 096/200 | Batch 0000/0175 | Loss: 0.1536
# Epoch: 096/200 | Batch 0100/0175 | Loss: 0.2009
# Epoch: 096/200 | Train: 94.09% | Validation: 76.88%
# Time elapsed: 77.02 min
# Epoch: 097/200 | Batch 0000/0175 | Loss: 0.1401
# Epoch: 097/200 | Batch 0100/0175 | Loss: 0.2461
# Epoch: 097/200 | Train: 94.12% | Validation: 76.88%
# Time elapsed: 77.86 min
# Epoch: 098/200 | Batch 0000/0175 | Loss: 0.1594
# Epoch: 098/200 | Batch 0100/0175 | Loss: 0.1556
# Epoch: 098/200 | Train: 94.15% | Validation: 76.88%
# Time elapsed: 78.70 min
# Epoch: 099/200 | Batch 0000/0175 | Loss: 0.1834
# Epoch: 099/200 | Batch 0100/0175 | Loss: 0.2175
# Epoch: 099/200 | Train: 94.24% | Validation: 76.88%
# Time elapsed: 79.52 min
# Epoch: 100/200 | Batch 0000/0175 | Loss: 0.1512
# Epoch: 100/200 | Batch 0100/0175 | Loss: 0.1485
# Epoch: 100/200 | Train: 94.14% | Validation: 76.88%
# Time elapsed: 80.37 min
# Epoch: 101/200 | Batch 0000/0175 | Loss: 0.2427
# Epoch: 101/200 | Batch 0100/0175 | Loss: 0.1657
# Epoch: 101/200 | Train: 94.33% | Validation: 76.88%
# Time elapsed: 81.25 min
# Epoch: 102/200 | Batch 0000/0175 | Loss: 0.2038
# Epoch: 102/200 | Batch 0100/0175 | Loss: 0.2029
# Epoch: 102/200 | Train: 94.28% | Validation: 76.88%
# Time elapsed: 82.12 min
# Epoch: 103/200 | Batch 0000/0175 | Loss: 0.1876
# Epoch: 103/200 | Batch 0100/0175 | Loss: 0.1587
# Epoch: 103/200 | Train: 94.21% | Validation: 76.88%
# Time elapsed: 83.00 min
# Epoch: 104/200 | Batch 0000/0175 | Loss: 0.2088
# Epoch: 104/200 | Batch 0100/0175 | Loss: 0.2321
# Epoch: 104/200 | Train: 94.22% | Validation: 76.88%
# Time elapsed: 83.84 min
# Epoch: 105/200 | Batch 0000/0175 | Loss: 0.1842
# Epoch: 105/200 | Batch 0100/0175 | Loss: 0.1509
# Epoch: 105/200 | Train: 94.17% | Validation: 76.88%
# Time elapsed: 84.68 min
# Epoch: 106/200 | Batch 0000/0175 | Loss: 0.1803
# Epoch: 106/200 | Batch 0100/0175 | Loss: 0.1535
# Epoch: 106/200 | Train: 94.24% | Validation: 76.88%
# Time elapsed: 85.49 min
# Epoch: 107/200 | Batch 0000/0175 | Loss: 0.2257
# Epoch: 107/200 | Batch 0100/0175 | Loss: 0.1630
# Epoch: 107/200 | Train: 94.26% | Validation: 76.88%
# Time elapsed: 86.32 min
# Epoch: 108/200 | Batch 0000/0175 | Loss: 0.1688
# Epoch: 108/200 | Batch 0100/0175 | Loss: 0.2490
# Epoch: 108/200 | Train: 94.24% | Validation: 76.88%
# Time elapsed: 87.17 min
# Epoch: 109/200 | Batch 0000/0175 | Loss: 0.2950
# Epoch: 109/200 | Batch 0100/0175 | Loss: 0.1751
# Epoch: 109/200 | Train: 94.20% | Validation: 76.88%
# Time elapsed: 88.01 min
# Epoch: 110/200 | Batch 0000/0175 | Loss: 0.2770
# Epoch: 110/200 | Batch 0100/0175 | Loss: 0.2328
# Epoch: 110/200 | Train: 94.30% | Validation: 76.88%
# Time elapsed: 88.84 min
# Epoch: 111/200 | Batch 0000/0175 | Loss: 0.1791
# Epoch: 111/200 | Batch 0100/0175 | Loss: 0.2073
# Epoch: 111/200 | Train: 94.24% | Validation: 76.88%
# Time elapsed: 89.69 min
# Epoch: 112/200 | Batch 0000/0175 | Loss: 0.1815
# Epoch: 112/200 | Batch 0100/0175 | Loss: 0.1572
# Epoch: 112/200 | Train: 94.25% | Validation: 76.88%
# Time elapsed: 90.53 min
# Epoch: 113/200 | Batch 0000/0175 | Loss: 0.1649
# Epoch: 113/200 | Batch 0100/0175 | Loss: 0.2243
# Epoch: 113/200 | Train: 94.35% | Validation: 76.88%
# Time elapsed: 91.37 min
# Epoch: 114/200 | Batch 0000/0175 | Loss: 0.1281
# Epoch: 114/200 | Batch 0100/0175 | Loss: 0.2141
# Epoch: 114/200 | Train: 94.16% | Validation: 76.88%
# Time elapsed: 92.20 min
# Epoch: 115/200 | Batch 0000/0175 | Loss: 0.1621
# Epoch: 115/200 | Batch 0100/0175 | Loss: 0.2115
# Epoch: 115/200 | Train: 94.15% | Validation: 76.88%
# Time elapsed: 93.01 min
# Epoch: 116/200 | Batch 0000/0175 | Loss: 0.1610
# Epoch: 116/200 | Batch 0100/0175 | Loss: 0.1986
# Epoch: 116/200 | Train: 94.12% | Validation: 76.88%
# Time elapsed: 93.85 min
# Epoch: 117/200 | Batch 0000/0175 | Loss: 0.1739
# Epoch: 117/200 | Batch 0100/0175 | Loss: 0.1655
# Epoch: 117/200 | Train: 94.20% | Validation: 76.88%
# Time elapsed: 94.66 min
# Epoch: 118/200 | Batch 0000/0175 | Loss: 0.1574
# Epoch: 118/200 | Batch 0100/0175 | Loss: 0.1985
# Epoch: 118/200 | Train: 94.35% | Validation: 76.88%
# Time elapsed: 95.44 min
# Epoch: 119/200 | Batch 0000/0175 | Loss: 0.2011
# Epoch: 119/200 | Batch 0100/0175 | Loss: 0.1634
# Epoch: 119/200 | Train: 94.34% | Validation: 76.88%
# Time elapsed: 96.26 min
# Epoch: 120/200 | Batch 0000/0175 | Loss: 0.2120
# Epoch: 120/200 | Batch 0100/0175 | Loss: 0.1946
# Epoch: 120/200 | Train: 94.25% | Validation: 76.88%
# Time elapsed: 97.08 min
# Epoch: 121/200 | Batch 0000/0175 | Loss: 0.1664
# Epoch: 121/200 | Batch 0100/0175 | Loss: 0.1522
# Epoch: 121/200 | Train: 94.11% | Validation: 76.88%
# Time elapsed: 97.91 min
# Epoch: 122/200 | Batch 0000/0175 | Loss: 0.1850
# Epoch: 122/200 | Batch 0100/0175 | Loss: 0.1506
# Epoch: 122/200 | Train: 94.14% | Validation: 76.88%
# Time elapsed: 98.71 min
# Epoch: 123/200 | Batch 0000/0175 | Loss: 0.2183
# Epoch: 123/200 | Batch 0100/0175 | Loss: 0.1814
# Epoch: 123/200 | Train: 94.22% | Validation: 76.88%
# Time elapsed: 99.53 min
# Epoch: 124/200 | Batch 0000/0175 | Loss: 0.1885
# Epoch: 124/200 | Batch 0100/0175 | Loss: 0.1228
# Epoch: 124/200 | Train: 94.13% | Validation: 76.88%
# Time elapsed: 100.35 min
# Epoch: 125/200 | Batch 0000/0175 | Loss: 0.1794
# Epoch: 125/200 | Batch 0100/0175 | Loss: 0.2526
# Epoch: 125/200 | Train: 94.14% | Validation: 76.88%
# Time elapsed: 101.13 min
# Epoch: 126/200 | Batch 0000/0175 | Loss: 0.1881
# Epoch: 126/200 | Batch 0100/0175 | Loss: 0.1699
# Epoch: 126/200 | Train: 94.23% | Validation: 76.88%
# Time elapsed: 101.94 min
# Epoch: 127/200 | Batch 0000/0175 | Loss: 0.1858
# Epoch: 127/200 | Batch 0100/0175 | Loss: 0.2267
# Epoch: 127/200 | Train: 94.21% | Validation: 76.88%
# Time elapsed: 102.75 min
# Epoch: 128/200 | Batch 0000/0175 | Loss: 0.1286
# Epoch: 128/200 | Batch 0100/0175 | Loss: 0.1288
# Epoch: 128/200 | Train: 94.21% | Validation: 76.88%
# Time elapsed: 103.54 min
# Epoch: 129/200 | Batch 0000/0175 | Loss: 0.1389
# Epoch: 129/200 | Batch 0100/0175 | Loss: 0.1840
# Epoch: 129/200 | Train: 94.19% | Validation: 76.88%
# Time elapsed: 104.34 min
# Epoch: 130/200 | Batch 0000/0175 | Loss: 0.1938
# Epoch: 130/200 | Batch 0100/0175 | Loss: 0.1794
# Epoch: 130/200 | Train: 94.21% | Validation: 76.88%
# Time elapsed: 105.14 min
# Epoch: 131/200 | Batch 0000/0175 | Loss: 0.2066
# Epoch: 131/200 | Batch 0100/0175 | Loss: 0.2240
# Epoch: 131/200 | Train: 94.37% | Validation: 76.88%
# Time elapsed: 105.94 min
# Epoch: 132/200 | Batch 0000/0175 | Loss: 0.1481
# Epoch: 132/200 | Batch 0100/0175 | Loss: 0.1045
# Epoch: 132/200 | Train: 94.25% | Validation: 76.88%
# Time elapsed: 106.74 min
# Epoch: 133/200 | Batch 0000/0175 | Loss: 0.1839
# Epoch: 133/200 | Batch 0100/0175 | Loss: 0.1974
# Epoch: 133/200 | Train: 94.17% | Validation: 76.88%
# Time elapsed: 107.53 min
# Epoch: 134/200 | Batch 0000/0175 | Loss: 0.1660
# Epoch: 134/200 | Batch 0100/0175 | Loss: 0.1319
# Epoch: 134/200 | Train: 94.15% | Validation: 76.88%
# Time elapsed: 108.32 min
# Epoch: 135/200 | Batch 0000/0175 | Loss: 0.1854
# Epoch: 135/200 | Batch 0100/0175 | Loss: 0.1919
# Epoch: 135/200 | Train: 94.23% | Validation: 76.88%
# Time elapsed: 109.13 min
# Epoch: 136/200 | Batch 0000/0175 | Loss: 0.1995
# Epoch: 136/200 | Batch 0100/0175 | Loss: 0.1877
# Epoch: 136/200 | Train: 94.14% | Validation: 76.88%
# Time elapsed: 109.94 min
# Epoch: 137/200 | Batch 0000/0175 | Loss: 0.1683
# Epoch: 137/200 | Batch 0100/0175 | Loss: 0.1159
# Epoch: 137/200 | Train: 94.06% | Validation: 76.88%
# Time elapsed: 110.72 min
# Epoch: 138/200 | Batch 0000/0175 | Loss: 0.1790
# Epoch: 138/200 | Batch 0100/0175 | Loss: 0.1710
# Epoch: 138/200 | Train: 94.18% | Validation: 76.88%
# Time elapsed: 111.53 min
# Epoch: 139/200 | Batch 0000/0175 | Loss: 0.1755
# Epoch: 139/200 | Batch 0100/0175 | Loss: 0.1468
# Epoch: 139/200 | Train: 94.09% | Validation: 76.88%
# Time elapsed: 112.33 min
# Epoch: 140/200 | Batch 0000/0175 | Loss: 0.2015
# Epoch: 140/200 | Batch 0100/0175 | Loss: 0.2020
# Epoch: 140/200 | Train: 94.33% | Validation: 76.88%
# Time elapsed: 113.13 min
# Epoch: 141/200 | Batch 0000/0175 | Loss: 0.1941
# Epoch: 141/200 | Batch 0100/0175 | Loss: 0.1798
# Epoch: 141/200 | Train: 94.24% | Validation: 76.88%
# Time elapsed: 113.95 min
# Epoch: 142/200 | Batch 0000/0175 | Loss: 0.1584
# Epoch: 142/200 | Batch 0100/0175 | Loss: 0.2815
# Epoch: 142/200 | Train: 94.28% | Validation: 76.88%
# Time elapsed: 114.77 min
# Epoch: 143/200 | Batch 0000/0175 | Loss: 0.1383
# Epoch: 143/200 | Batch 0100/0175 | Loss: 0.2260
# Epoch: 143/200 | Train: 94.28% | Validation: 76.88%
# Time elapsed: 115.58 min
# Epoch: 144/200 | Batch 0000/0175 | Loss: 0.1570
# Epoch: 144/200 | Batch 0100/0175 | Loss: 0.1955
# Epoch: 144/200 | Train: 94.12% | Validation: 76.88%
# Time elapsed: 116.39 min
# Epoch: 145/200 | Batch 0000/0175 | Loss: 0.1776
# Epoch: 145/200 | Batch 0100/0175 | Loss: 0.1355
# Epoch: 145/200 | Train: 94.11% | Validation: 76.88%
# Time elapsed: 117.23 min
# Epoch: 146/200 | Batch 0000/0175 | Loss: 0.1234
# Epoch: 146/200 | Batch 0100/0175 | Loss: 0.1682
# Epoch: 146/200 | Train: 94.13% | Validation: 76.88%
# Time elapsed: 118.06 min
# Epoch: 147/200 | Batch 0000/0175 | Loss: 0.1641
# Epoch: 147/200 | Batch 0100/0175 | Loss: 0.1065
# Epoch: 147/200 | Train: 94.23% | Validation: 76.88%
# Time elapsed: 118.90 min
# Epoch: 148/200 | Batch 0000/0175 | Loss: 0.1833
# Epoch: 148/200 | Batch 0100/0175 | Loss: 0.2538
# Epoch: 148/200 | Train: 94.26% | Validation: 76.88%
# Time elapsed: 119.72 min
# Epoch: 149/200 | Batch 0000/0175 | Loss: 0.2658
# Epoch: 149/200 | Batch 0100/0175 | Loss: 0.2374
# Epoch: 149/200 | Train: 94.08% | Validation: 76.88%
# Time elapsed: 120.54 min
# Epoch: 150/200 | Batch 0000/0175 | Loss: 0.0931
# Epoch: 150/200 | Batch 0100/0175 | Loss: 0.1640
# Epoch: 150/200 | Train: 94.27% | Validation: 76.88%
# Time elapsed: 121.36 min
# Epoch: 151/200 | Batch 0000/0175 | Loss: 0.1415
# Epoch: 151/200 | Batch 0100/0175 | Loss: 0.1393
# Epoch: 151/200 | Train: 94.28% | Validation: 76.88%
# Time elapsed: 122.18 min
# Epoch: 152/200 | Batch 0000/0175 | Loss: 0.1629
# Epoch: 152/200 | Batch 0100/0175 | Loss: 0.1715
# Epoch: 152/200 | Train: 94.09% | Validation: 76.88%
# Time elapsed: 123.00 min
# Epoch: 153/200 | Batch 0000/0175 | Loss: 0.1996
# Epoch: 153/200 | Batch 0100/0175 | Loss: 0.2042
# Epoch: 153/200 | Train: 94.16% | Validation: 76.88%
# Time elapsed: 123.82 min
# Epoch: 154/200 | Batch 0000/0175 | Loss: 0.1550
# Epoch: 154/200 | Batch 0100/0175 | Loss: 0.1384
# Epoch: 154/200 | Train: 94.23% | Validation: 76.88%
# Time elapsed: 124.64 min
# Epoch: 155/200 | Batch 0000/0175 | Loss: 0.1781
# Epoch: 155/200 | Batch 0100/0175 | Loss: 0.1797
# Epoch: 155/200 | Train: 94.16% | Validation: 76.88%
# Time elapsed: 125.45 min
# Epoch: 156/200 | Batch 0000/0175 | Loss: 0.2300
# Epoch: 156/200 | Batch 0100/0175 | Loss: 0.1831
# Epoch: 156/200 | Train: 94.23% | Validation: 76.88%
# Time elapsed: 126.26 min
# Epoch: 157/200 | Batch 0000/0175 | Loss: 0.1814
# Epoch: 157/200 | Batch 0100/0175 | Loss: 0.2137
# Epoch: 157/200 | Train: 94.17% | Validation: 76.88%
# Time elapsed: 127.08 min
# Epoch: 158/200 | Batch 0000/0175 | Loss: 0.2273
# Epoch: 158/200 | Batch 0100/0175 | Loss: 0.1634
# Epoch: 158/200 | Train: 94.26% | Validation: 76.88%
# Time elapsed: 127.91 min
# Epoch: 159/200 | Batch 0000/0175 | Loss: 0.1943
# Epoch: 159/200 | Batch 0100/0175 | Loss: 0.1481
# Epoch: 159/200 | Train: 94.13% | Validation: 76.88%
# Time elapsed: 128.74 min
# Epoch: 160/200 | Batch 0000/0175 | Loss: 0.1993
# Epoch: 160/200 | Batch 0100/0175 | Loss: 0.2071
# Epoch: 160/200 | Train: 94.25% | Validation: 76.88%
# Time elapsed: 129.56 min
# Epoch: 161/200 | Batch 0000/0175 | Loss: 0.1825
# Epoch: 161/200 | Batch 0100/0175 | Loss: 0.1895
# Epoch: 161/200 | Train: 94.26% | Validation: 76.88%
# Time elapsed: 130.40 min
# Epoch: 162/200 | Batch 0000/0175 | Loss: 0.2413
# Epoch: 162/200 | Batch 0100/0175 | Loss: 0.2329
# Epoch: 162/200 | Train: 94.03% | Validation: 76.88%
# Time elapsed: 131.24 min
# Epoch: 163/200 | Batch 0000/0175 | Loss: 0.1826
# Epoch: 163/200 | Batch 0100/0175 | Loss: 0.1851
# Epoch: 163/200 | Train: 94.13% | Validation: 76.88%
# Time elapsed: 132.07 min
# Epoch: 164/200 | Batch 0000/0175 | Loss: 0.2208
# Epoch: 164/200 | Batch 0100/0175 | Loss: 0.2495
# Epoch: 164/200 | Train: 94.25% | Validation: 76.88%
# Time elapsed: 132.88 min
# Epoch: 165/200 | Batch 0000/0175 | Loss: 0.1714
# Epoch: 165/200 | Batch 0100/0175 | Loss: 0.2091
# Epoch: 165/200 | Train: 94.09% | Validation: 76.88%
# Time elapsed: 133.71 min
# Epoch: 166/200 | Batch 0000/0175 | Loss: 0.2025
# Epoch: 166/200 | Batch 0100/0175 | Loss: 0.2053
# Epoch: 166/200 | Train: 94.06% | Validation: 76.88%
# Time elapsed: 134.54 min
# Epoch: 167/200 | Batch 0000/0175 | Loss: 0.2543
# Epoch: 167/200 | Batch 0100/0175 | Loss: 0.1823
# Epoch: 167/200 | Train: 94.25% | Validation: 76.88%
# Time elapsed: 135.37 min
# Epoch: 168/200 | Batch 0000/0175 | Loss: 0.1309
# Epoch: 168/200 | Batch 0100/0175 | Loss: 0.1192
# Epoch: 168/200 | Train: 94.14% | Validation: 76.88%
# Time elapsed: 136.19 min
# Epoch: 169/200 | Batch 0000/0175 | Loss: 0.1449
# Epoch: 169/200 | Batch 0100/0175 | Loss: 0.1613
# Epoch: 169/200 | Train: 94.19% | Validation: 76.88%
# Time elapsed: 137.00 min
# Epoch: 170/200 | Batch 0000/0175 | Loss: 0.2499
# Epoch: 170/200 | Batch 0100/0175 | Loss: 0.1399
# Epoch: 170/200 | Train: 94.24% | Validation: 76.88%
# Time elapsed: 137.82 min
# Epoch: 171/200 | Batch 0000/0175 | Loss: 0.1583
# Epoch: 171/200 | Batch 0100/0175 | Loss: 0.1706
# Epoch: 171/200 | Train: 94.26% | Validation: 76.88%
# Time elapsed: 138.64 min
# Epoch: 172/200 | Batch 0000/0175 | Loss: 0.0797
# Epoch: 172/200 | Batch 0100/0175 | Loss: 0.2302
# Epoch: 172/200 | Train: 94.13% | Validation: 76.88%
# Time elapsed: 139.46 min
# Epoch: 173/200 | Batch 0000/0175 | Loss: 0.1537
# Epoch: 173/200 | Batch 0100/0175 | Loss: 0.1470
# Epoch: 173/200 | Train: 94.08% | Validation: 76.88%
# Time elapsed: 140.27 min
# Epoch: 174/200 | Batch 0000/0175 | Loss: 0.1584
# Epoch: 174/200 | Batch 0100/0175 | Loss: 0.1106
# Epoch: 174/200 | Train: 94.25% | Validation: 76.88%
# Time elapsed: 141.09 min
# Epoch: 175/200 | Batch 0000/0175 | Loss: 0.2092
# Epoch: 175/200 | Batch 0100/0175 | Loss: 0.2185
# Epoch: 175/200 | Train: 94.32% | Validation: 76.88%
# Time elapsed: 141.92 min
# Epoch: 176/200 | Batch 0000/0175 | Loss: 0.2082
# Epoch: 176/200 | Batch 0100/0175 | Loss: 0.2222
# Epoch: 176/200 | Train: 94.18% | Validation: 76.88%
# Time elapsed: 142.74 min
# Epoch: 177/200 | Batch 0000/0175 | Loss: 0.2412
# Epoch: 177/200 | Batch 0100/0175 | Loss: 0.2252
# Epoch: 177/200 | Train: 94.24% | Validation: 76.88%
# Time elapsed: 143.55 min
# Epoch: 178/200 | Batch 0000/0175 | Loss: 0.2165
# Epoch: 178/200 | Batch 0100/0175 | Loss: 0.1293
# Epoch: 178/200 | Train: 94.19% | Validation: 76.88%
# Time elapsed: 144.38 min
# Epoch: 179/200 | Batch 0000/0175 | Loss: 0.1416
# Epoch: 179/200 | Batch 0100/0175 | Loss: 0.1675
# Epoch: 179/200 | Train: 94.35% | Validation: 76.88%
# Time elapsed: 145.22 min
# Epoch: 180/200 | Batch 0000/0175 | Loss: 0.1009
# Epoch: 180/200 | Batch 0100/0175 | Loss: 0.1624
# Epoch: 180/200 | Train: 94.17% | Validation: 76.88%
# Time elapsed: 146.05 min
# Epoch: 181/200 | Batch 0000/0175 | Loss: 0.1657
# Epoch: 181/200 | Batch 0100/0175 | Loss: 0.2086
# Epoch: 181/200 | Train: 94.28% | Validation: 76.88%
# Time elapsed: 146.90 min
# Epoch: 182/200 | Batch 0000/0175 | Loss: 0.1626
# Epoch: 182/200 | Batch 0100/0175 | Loss: 0.1387
# Epoch: 182/200 | Train: 94.11% | Validation: 76.88%
# Time elapsed: 147.72 min
# Epoch: 183/200 | Batch 0000/0175 | Loss: 0.1494
# Epoch: 183/200 | Batch 0100/0175 | Loss: 0.1534
# Epoch: 183/200 | Train: 94.22% | Validation: 76.88%
# Time elapsed: 148.54 min
# Epoch: 184/200 | Batch 0000/0175 | Loss: 0.1888
# Epoch: 184/200 | Batch 0100/0175 | Loss: 0.1463
# Epoch: 184/200 | Train: 94.09% | Validation: 76.88%
# Time elapsed: 149.36 min
# Epoch: 185/200 | Batch 0000/0175 | Loss: 0.1556
# Epoch: 185/200 | Batch 0100/0175 | Loss: 0.1970
# Epoch: 185/200 | Train: 94.24% | Validation: 76.88%
# Time elapsed: 150.19 min
# Epoch: 186/200 | Batch 0000/0175 | Loss: 0.2427
# Epoch: 186/200 | Batch 0100/0175 | Loss: 0.1345
# Epoch: 186/200 | Train: 94.23% | Validation: 76.88%
# Time elapsed: 150.99 min
# Epoch: 187/200 | Batch 0000/0175 | Loss: 0.2186
# Epoch: 187/200 | Batch 0100/0175 | Loss: 0.2282
# Epoch: 187/200 | Train: 94.14% | Validation: 76.88%
# Time elapsed: 151.82 min
# Epoch: 188/200 | Batch 0000/0175 | Loss: 0.1765
# Epoch: 188/200 | Batch 0100/0175 | Loss: 0.2275
# Epoch: 188/200 | Train: 94.19% | Validation: 76.88%
# Time elapsed: 152.65 min
# Epoch: 189/200 | Batch 0000/0175 | Loss: 0.1467
# Epoch: 189/200 | Batch 0100/0175 | Loss: 0.1988
# Epoch: 189/200 | Train: 94.20% | Validation: 76.88%
# Time elapsed: 153.49 min
# Epoch: 190/200 | Batch 0000/0175 | Loss: 0.2286
# Epoch: 190/200 | Batch 0100/0175 | Loss: 0.1912
# Epoch: 190/200 | Train: 94.19% | Validation: 76.88%
# Time elapsed: 154.30 min
# Epoch: 191/200 | Batch 0000/0175 | Loss: 0.1446
# Epoch: 191/200 | Batch 0100/0175 | Loss: 0.1722
# Epoch: 191/200 | Train: 94.07% | Validation: 76.88%
# Time elapsed: 155.13 min
# Epoch: 192/200 | Batch 0000/0175 | Loss: 0.1697
# Epoch: 192/200 | Batch 0100/0175 | Loss: 0.1698
# Epoch: 192/200 | Train: 94.16% | Validation: 76.88%
# Time elapsed: 155.98 min
# Epoch: 193/200 | Batch 0000/0175 | Loss: 0.2221
# Epoch: 193/200 | Batch 0100/0175 | Loss: 0.1386
# Epoch: 193/200 | Train: 94.16% | Validation: 76.88%
# Time elapsed: 156.82 min
# Epoch: 194/200 | Batch 0000/0175 | Loss: 0.1722
# Epoch: 194/200 | Batch 0100/0175 | Loss: 0.1628
# Epoch: 194/200 | Train: 94.25% | Validation: 76.88%
# Time elapsed: 157.66 min
# Epoch: 195/200 | Batch 0000/0175 | Loss: 0.1861
# Epoch: 195/200 | Batch 0100/0175 | Loss: 0.1912
# Epoch: 195/200 | Train: 94.15% | Validation: 76.88%
# Time elapsed: 158.46 min
# Epoch: 196/200 | Batch 0000/0175 | Loss: 0.2341
# Epoch: 196/200 | Batch 0100/0175 | Loss: 0.1979
# Epoch: 196/200 | Train: 94.24% | Validation: 76.88%
# Time elapsed: 159.30 min
# Epoch: 197/200 | Batch 0000/0175 | Loss: 0.1711
# Epoch: 197/200 | Batch 0100/0175 | Loss: 0.1855
# Epoch: 197/200 | Train: 94.29% | Validation: 76.88%
# Time elapsed: 160.13 min
# Epoch: 198/200 | Batch 0000/0175 | Loss: 0.2305
# Epoch: 198/200 | Batch 0100/0175 | Loss: 0.2819
# Epoch: 198/200 | Train: 94.09% | Validation: 76.88%
# Time elapsed: 160.96 min
# Epoch: 199/200 | Batch 0000/0175 | Loss: 0.1395
# Epoch: 199/200 | Batch 0100/0175 | Loss: 0.2229
# Epoch: 199/200 | Train: 94.28% | Validation: 76.88%
# Time elapsed: 161.78 min
# Epoch: 200/200 | Batch 0000/0175 | Loss: 0.1727
# Epoch: 200/200 | Batch 0100/0175 | Loss: 0.1884
# Epoch: 200/200 | Train: 94.22% | Validation: 76.88%
# Time elapsed: 162.59 min
# Total Training Time: 162.59 min
# Test accuracy 76.11%

# %%
def plot_training_loss(minibatch_loss_list, num_epochs, iter_per_epoch,
                       results_dir=None, averaging_iterations=100):

    plt.figure()
    ax1 = plt.subplot(1, 1, 1)
    ax1.plot(range(len(minibatch_loss_list)),
             (minibatch_loss_list), label='Minibatch Loss')

    if len(minibatch_loss_list) > 1000:
        ax1.set_ylim([
            0, np.max(minibatch_loss_list[1000:])*1.5
            ])
    ax1.set_xlabel('Iterations')
    ax1.set_ylabel('Loss')

    ax1.plot(np.convolve(minibatch_loss_list,
                         np.ones(averaging_iterations,)/averaging_iterations,
                         mode='valid'),
             label='Running Average')
    ax1.legend()

    ###################
    # Set scond x-axis
    ax2 = ax1.twiny()
    newlabel = list(range(num_epochs+1))

    newpos = [e*iter_per_epoch for e in newlabel]

    ax2.set_xticks(newpos[::10])
    ax2.set_xticklabels(newlabel[::10])

    ax2.xaxis.set_ticks_position('bottom')
    ax2.xaxis.set_label_position('bottom')
    ax2.spines['bottom'].set_position(('outward', 45))
    ax2.set_xlabel('Epochs')
    ax2.set_xlim(ax1.get_xlim())
    ###################

    plt.tight_layout()

    if results_dir is not None:
        image_path = os.path.join(results_dir, 'plot_training_loss.pdf')
        plt.savefig(image_path)


def plot_accuracy(train_acc_list, valid_acc_list, results_dir):

    num_epochs = len(train_acc_list)

    plt.plot(np.arange(1, num_epochs+1),
             train_acc_list, label='Training')
    plt.plot(np.arange(1, num_epochs+1),
             valid_acc_list, label='Validation')

    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    plt.tight_layout()

    if results_dir is not None:
        image_path = os.path.join(
            results_dir, 'plot_acc_training_validation.pdf')
        plt.savefig(image_path)


def show_examples(model, data_loader, unnormalizer=None, class_dict=None):


    for batch_idx, (features, targets) in enumerate(data_loader):

        with torch.no_grad():
            features = features
            targets = targets
            logits = model(features)
            predictions = torch.argmax(logits, dim=1)
        break

    fig, axes = plt.subplots(nrows=3, ncols=5,
                             sharex=True, sharey=True)

    if unnormalizer is not None:
        for idx in range(features.shape[0]):
            features[idx] = unnormalizer(features[idx])
    nhwc_img = np.transpose(features, axes=(0, 2, 3, 1))

    if nhwc_img.shape[-1] == 1:
        nhw_img = np.squeeze(nhwc_img.numpy(), axis=3)

        for idx, ax in enumerate(axes.ravel()):
            ax.imshow(nhw_img[idx], cmap='binary')
            if class_dict is not None:
                ax.title.set_text(f'P: {class_dict[predictions[idx].item()]}'
                                  f'\nT: {class_dict[targets[idx].item()]}')
            else:
                ax.title.set_text(f'P: {predictions[idx]} | T: {targets[idx]}')
            ax.axison = False

    else:

        for idx, ax in enumerate(axes.ravel()):
            ax.imshow(nhwc_img[idx])
            if class_dict is not None:
                ax.title.set_text(f'P: {class_dict[predictions[idx].item()]}'
                                  f'\nT: {class_dict[targets[idx].item()]}')
            else:
                ax.title.set_text(f'P: {predictions[idx]} | T: {targets[idx]}')
            ax.axison = False
    plt.tight_layout()
    plt.show()


def plot_confusion_matrix(conf_mat,
                          hide_spines=False,
                          hide_ticks=False,
                          figsize=None,
                          cmap=None,
                          colorbar=False,
                          show_absolute=True,
                          show_normed=False,
                          class_names=None):

    if not (show_absolute or show_normed):
        raise AssertionError('Both show_absolute and show_normed are False')
    if class_names is not None and len(class_names) != len(conf_mat):
        raise AssertionError('len(class_names) should be equal to number of'
                             'classes in the dataset')

    total_samples = conf_mat.sum(axis=1)[:, np.newaxis]
    normed_conf_mat = conf_mat.astype('float') / total_samples

    fig, ax = plt.subplots(figsize=figsize)
    ax.grid(False)
    if cmap is None:
        cmap = plt.cm.Blues

    if figsize is None:
        figsize = (len(conf_mat)*1.25, len(conf_mat)*1.25)

    if show_normed:
        matshow = ax.matshow(normed_conf_mat, cmap=cmap)
    else:
        matshow = ax.matshow(conf_mat, cmap=cmap)

    if colorbar:
        fig.colorbar(matshow)

    for i in range(conf_mat.shape[0]):
        for j in range(conf_mat.shape[1]):
            cell_text = ""
            if show_absolute:
                cell_text += format(conf_mat[i, j], 'd')
                if show_normed:
                    cell_text += "\n" + '('
                    cell_text += format(normed_conf_mat[i, j], '.2f') + ')'
            else:
                cell_text += format(normed_conf_mat[i, j], '.2f')
            ax.text(x=j,
                    y=i,
                    s=cell_text,
                    va='center',
                    ha='center',
                    color="white" if normed_conf_mat[i, j] > 0.5 else "black")

    if class_names is not None:
        tick_marks = np.arange(len(class_names))
        plt.xticks(tick_marks, class_names, rotation=90)
        plt.yticks(tick_marks, class_names)

    if hide_spines:
        ax.spines['right'].set_visible(False)
        ax.spines['top'].set_visible(False)
        ax.spines['left'].set_visible(False)
        ax.spines['bottom'].set_visible(False)
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')
    if hide_ticks:
        ax.axes.get_yaxis().set_ticks([])
        ax.axes.get_xaxis().set_ticks([])

    plt.xlabel('predicted label')
    plt.ylabel('true label')
    return fig, ax

# %%
plot_training_loss(minibatch_loss_list=minibatch_loss_list,
                   num_epochs=NUM_EPOCHS,
                   iter_per_epoch=len(train_loader),
                   results_dir=None,
                   averaging_iterations=200)
plt.show()

plot_accuracy(train_acc_list=train_acc_list,
              valid_acc_list=valid_acc_list,
              results_dir=None)
plt.ylim([60, 100])
plt.show()

# %%
class UnNormalize(object):
    def __init__(self, mean, std):
        self.mean = mean
        self.std = std

    def __call__(self, tensor):
        """
        Parameters:
        ------------
        tensor (Tensor): Tensor image of size (C, H, W) to be normalized.

        Returns:
        ------------
        Tensor: Normalized image.
        """
        for t, m, s in zip(tensor, self.mean, self.std):
            t.mul_(s).add_(m)
        return tensor

# %%
model.cpu()
unnormalizer = UnNormalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
class_dict = {0: 'airplane',
              1: 'automobile',
              2: 'bird',
              3: 'cat',
              4: 'deer',
              5: 'dog',
              6: 'frog',
              7: 'horse',
              8: 'ship',
              9: 'truck'}

show_examples(model=model, data_loader=test_loader, unnormalizer=unnormalizer, class_dict=class_dict)

# %%
from itertools import product
def compute_confusion_matrix(model, data_loader, device):

    all_targets, all_predictions = [], []
    with torch.no_grad():

        for i, (features, targets) in enumerate(data_loader):

            features = features.to(device)
            targets = targets
            logits = model(features)
            _, predicted_labels = torch.max(logits, 1)
            all_targets.extend(targets.to('cpu'))
            all_predictions.extend(predicted_labels.to('cpu'))

    all_predictions = all_predictions
    all_predictions = np.array(all_predictions)
    all_targets = np.array(all_targets)

    class_labels = np.unique(np.concatenate((all_targets, all_predictions)))
    if class_labels.shape[0] == 1:
        if class_labels[0] != 0:
            class_labels = np.array([0, class_labels[0]])
        else:
            class_labels = np.array([class_labels[0], 1])
    n_labels = class_labels.shape[0]
    lst = []
    z = list(zip(all_targets, all_predictions))
    for combi in product(class_labels, repeat=2):
        lst.append(z.count(combi))
    mat = np.asarray(lst)[:, None].reshape(n_labels, n_labels)
    return mat

# %%
mat = compute_confusion_matrix(model=model, data_loader=test_loader, device=torch.device('cpu'))
plot_confusion_matrix(mat, class_names=class_dict.values())
plt.show()
