# %%
import numpy as np

# %%
def forloop(x, w):
    z = 0
    for i in range(len(x)):
        z = x[i] * w[i]
    return z

def listcomprehension(x, w):
    return sum(x_i * w_i for x_i, w_i in zip(x, w))

# %%
x = np.random.rand(100)
w = np.random.rand(100)
x_vec, w_vec = np.array(x), np.array(w)

# %%
# %timeit -r 100 -n 10 forloop(x, w)
# Out:
# The slowest run took 8.31 times longer than the fastest. This could mean that an intermediate result is being cached.
# 42 μs ± 26.7 μs per loop (mean ± std. dev. of 100 runs, 10 loops each)

# %%
# %timeit -r 100 -n 10 listcomprehension(x, w)
# Out:
# The slowest run took 7.16 times longer than the fastest. This could mean that an intermediate result is being cached.
# 46.9 μs ± 23.5 μs per loop (mean ± std. dev. of 100 runs, 10 loops each)

# %%
def vectorization(x_vec, w_vec):
    return x_vec.dot(w_vec)

# %%
# %timeit -r 100 -n 10 vectorization(x_vec, w_vec)
# Out:
# The slowest run took 39.92 times longer than the fastest. This could mean that an intermediate result is being cached.
# 2.09 μs ± 4.64 μs per loop (mean ± std. dev. of 100 runs, 10 loops each)

# %%
# This is macbook
# The slowest run took 13.50 times longer than the fastest. This could mean that an intermediate result is being cached.
# 14.5 µs ± 7.73 µs per loop (mean ± std. dev. of 100 runs, 10 loops each)
